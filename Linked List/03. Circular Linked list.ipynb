# %% [markdown]
# ### Circular Linked List
# In a Circular Linked List, the last node points back to the first node

# %% [markdown]
# --- Similar to all above files
#
# --- here last.next = self.head
#
# -- self.head.prev = last

# %% [markdown]
# -- Here for traversing
#
# -- while t.next  != self.head
